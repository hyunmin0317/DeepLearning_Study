# %%
import numpy as np
print(np.__version__)	# 1.16.3
# Out:
# 1.19.5

# %%
my_arr = np.array([[10, 20, 30], [40, 50, 60]])
print(my_arr)
# [[10 20 30]
#  [40 50 60]]
# Out:
# [[10 20 30]
#  [40 50 60]]

# %%
type(my_arr)
#numpy.ndarray
# Out:
# numpy.ndarray

# %%
my_arr[0][2]	# 30
# Out:
# 30

# %%
np.sum(my_arr)	# 210
# Out:
# 210
